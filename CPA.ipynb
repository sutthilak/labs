# %%
#........................................................................................................................................................................................................
#..........................................................................................................................,%,...................................................../(....................
#........................................................................................................................./#........%@#.......,%@&*............../@&........*@@(....,&,..................
#........................................................................................................................,&........../@@,...*@@%..................*@@*....,@@#.......*%..................
#..................................................................................,@@@@@@@(...&@@@@@@&...&@,....*@&.....%(............&@/(@@/.....................,@@(.,&@%..........&*.................
#.................................................................................(@&...../..(@%.....,@&../@(...#@(......&/.............%@@*.........................%@@@&............%(.................
#.................................................................................@@........,@@,...../@%..,@@.,@@,.......&/..........*@@%,@@*.........................&@*.............%(.................
#.................................................................................&@*...(@@..&@/...,%@&....#@#@%.........##........(@@(....%@#.......................(@&..............&*.................
#..................................................................................(@@@@%,....*&@@@@(......,@@/...........&,.....%@@*.......*@@,......./@&...........&@,............./#..................
#.........................................................................................................................,%...........................(&...........................,%...................
#........,&/-#-&&,..................................&@@@@@@@@@@@&...........................................................**.....................................................(.....................
#.......,@%.....%@,..................................................@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@....
#.......*@%.....#@,...#/....*%*.........#*....*%*...%@@@@@@@@@@@&........................................................................................................................................
#.......*@@%...,@/.....#&.(@*............@#.,&#.................................,##################################################################################################################......
#.......*@#.............&@*...............#@&...................................(........................................................................................................................
#.......*@#..........,@#..%%..............#%...................................*/...........................................%@%......*@@#............................................&@(.......&@%.......
#.................................%,...........................................(...../*......//,..,(%&%(,....,/,,#%(.........*@@,..(@@/........*/,.....,/*..,/#%%#*...../*.(%#........#@&....%@&,........
#............................................................................./*.....&@.....&@,./@@/.../@&...%@@(..............&@@@&,........../@(....(@#.,@@(,..*@@...(@@#,.,........./@&,%@&,..........
#.....................................................................,**@....(......(@(../@%..../%&&&@@@#..*@&...............*@@@@............,@@...&@,...*%&&&@@@&..,@@,..............,@@@,............
#........................................................................*@,.(........@&.%@*...%@%.....@@,..&@,.............(@@/..@@/...........#@/*@%.../@&.....%@/..(@/................@@..............
#.........................................................................,@//........#@@&.....#@@/*(@@@&..*@#............%@@,.....#@%..........,@@@/..../@@(*/&@@@..,@@................%@#..............
#..........................................................................*%....................,/*.......................................................,**,..........................................
#........................................................................................................................................................................................................

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.matlib import repmat


ctfile1 = "ciphertext-00112233445566778899aabbccddeeff.txt"
ctfile2 = "ciphertext-unknown_key.txt"
ptfile1 = "plaintext-00112233445566778899aabbccddeeff.txt"
ptfile2 = "plaintext-unknown_key.txt"
trfile1 = "traces-00112233445566778899aabbccddeeff.bin"
trfile1 = "traces-00112233445566778899aabbccddeeff.npy"
trfile2 = "traces-unknown_key.bin"
trfile2 = "traces-unknown_key.npy"

Sbox = np.array([
            
            ])

# %%
#################################################
#                                               #
#                                               #
#        C O D E   S T A R T S   H E R E        #
#                                               #
#                                               #
#################################################

tohex = np.vectorize(lambda x: int(x, 16))

def myin(filename):
    with open(filename, 'r') as f:
        data = f.readlines()[:-1]
    return tohex(np.array([line[:-2].split(" ") for line in data]))    

def myload(filename):
    return np.load(filename)

def myload2(fname,trlen=370000,start=0,len=370000,n=200):
    myfile = open(fname, 'rb')
    traces = np.zeros((n, len))
    myfile.seek(start)
    for i in range(n):      
        if len+start > trlen:
            t = [int.from_bytes(myfile.read(1), byteorder='big') for i in range(len-start)]
        else:
            t = [int.from_bytes(myfile.read(1), byteorder='big') for i in range(len)]
        traces[i] = t
    myfile.close()
    return traces

def mycorr(x,y):
    xr,xc = x.shape
    yr,yc = y.shape
    assert xr==yr, "Matrix row count mismatch"     

    x = x - x.mean(0)
    y = y - y.mean(0)
    C = x.T.dot(y)
    xsq = np.atleast_2d(np.sqrt(np.sum(x**2, 0)))
    ysq = np.atleast_2d(np.sqrt(np.sum(y**2, 0)))
    C = np.divide(C, repmat(xsq.T, 1, yc))
    C = np.divide(C, repmat(ysq, xc, 1))
    return C

def hamming_w(a): #hamming weight
    a_bin=bin(a)[2:]
    return(sum(bit == '1' for bit in a_bin))
    
def hamming_d(a,b):# hamming distance 
    a_binary=bin(a)[2:].zfill(8)
    b_binary=bin(b)[2:].zfill(8)
    return sum(el1 != el2 for el1, el2 in zip(a_binary, b_binary))
    
def iv(key,byte,n): # intermedia values
    pt=plaintexts[:n,byte].astype("uint32")
    v=Sbox[pt^key]
    return(v)

# %%
#TODO:
#Select which files to open. Filenames defined at the top.
#Functions for loading are named the same as in the Matlab code.
#traces = myload(trfile1)
#plaintexts = myin(ptfile1)
traces = myload(trfile2)
plaintexts = myin(ptfile2)
#Use this to check that you loaded the files correctly
print("traces", traces.shape)
print("plaintexts", plaintexts.shape)

#TODO:
#After doing the next part you can come back here and change the
#start and stop values to remove the parts of the trace we don't need.
#E.g. let's make up some numbers. If the leakage window starts at x = 123456
#and the window ends at x = 246912 you set start and stop to those values
#respectively
#start =45200
start=0
#stop = traces.shape[1]
stop = 340000
traces = traces[:, start:stop]
#TODO:
#plot one of the power traces.
#Try to determine if you can see the 10 rounds of AES
#in the traces. Also, try to determine if keybytes are
#calculated in series (8-bit operations), 4 at a time
#(32-bit operations), or all parallely.

fig = plt.figure(figsize=(30,10))
plt.plot(traces[2])
plt.ylim(50,125)
#plt.xlim(0,2000)
plt.show()

#TODO:
#Plot only the first round (or two) of AES.
#Also plot vertical lines around where you think we will
#find the information leakage. To plot vertical lines
#you can use the command

fig2 = plt.figure(figsize=(30,10))
plt.plot(traces[2])
plt.ylim(0,200)
plt.xlim(0,37000)

plt.show()



#You may wish to delimit your traces around where
#the leakage point is to speed up computations later

#Tip: to get resizeable popup plots in jupyter notebook
#you can tell the backend to use a library such as 
#qt to handle the plotting in a new window. 
#Test this following code to see how:
#
#%matplotlib qt 
#plt.plot([1,2,3])
# Out:
# traces (149, 550000)
# plaintexts (149, 16)

# %%
  
plt.plot(traces[2])
  
# Drawing vertical line from 25 %
# of the y-axis length to 75 % 
# And also changing the linestyle
plt.axvline(x = 13000, ymin = 0.25, ymax = 2,
            linewidth = 1, linestyle ="--",
            color ='red')
  
plt.show()

# %%
traces = traces[:, 0:15000]
plt.plot(traces[2])

# %%
#TODO:
#for each possible value of the keybytes, formulate
#a power hypothesis. Make sure you understand what
#the power hypothesis represents and why we need it
#
#The Sbox for AES is provided in case you wish to 
#use it for your power hypothesis



#TODO:
#for each of the 16 subkeys, use your power hypothesis
#to calculate CC using the mycorr function.
#This function is an exact copy of the matlab function.
#
#The instructions say to make sure you know what CC is.
#Obviously one of the Cs is correlation. Which of these
#describes what CC is:
#1) Cross Correlation
#2) Correlation Coefficients
#3) Cumulative Correlation
#4) Central Correlation
#
#What shape would you expect the CC variable to have?
#Try plotting its shape and see if your guess was correct.
keys = []
m= 150 #num_traces lowest =  51 training set
traces = traces[:m,:]
for byte in range(16):
    
   
    #YOUR CODE HERE#
    cc=[]
    for key in range(0,256):
        
        ph=np.array([hamming_w(n) for n in iv(key,byte,m)])
        #ph=np.array([hamming_d(n,plaintexts[index,byte]^key) for index, n in enumerate(iv(key,byte,m))])
        ph=ph.reshape(ph.shape[0], 1)
        
        
        CC=(mycorr(ph,traces))
        
        cc.append(CC)
    max_val = -float("inf")
    max_arr_index = -1

    for i, arr in enumerate(cc):
        curr_max = np.amax(arr)
        if curr_max > max_val:
            max_val = curr_max
            max_arr_index = i

    #print("Maximum value:", max_val)
    #print("Byte:",byte,"Key:", max_arr_index)
    keys.append(max_arr_index)    

    #TODO:
    #Write code to find the correct keybyte.
    #You will want to print it. Depending on your code
    #you may have to print it inside the loop.

    
#NOTE: The amount of code you need to write in this section
#is very small. It can reasonably be done in 4 lines of
#code or less...
hex_k= [hex(k)[2:] for k in keys]
print(' '.join(hex_k))
# Out:
# 5 de ad be ef 42 0 68 61 63 6b 65 64 6b 65 79

# %%
for m in range(52,149):
    
    n_traces= traces[:m,:]
    keys = []
    for byte in range(16):


        #YOUR CODE HERE#
        cc=[]
        for key in range(0,256):

            #ph=np.array([hamming_w(n) for n in iv(key,byte)]).reshape(ph.shape[0], 1)
            ph=np.array([hamming_d(n,plaintexts[index,byte]^key) for index, n in enumerate(iv(key,byte,m))])
            ph=ph.reshape(ph.shape[0], 1)


            CC=(mycorr(ph,n_traces))

            cc.append(CC)
        max_val = -float("inf")
        max_arr_index = -1

        for i, arr in enumerate(cc):
            curr_max = np.amax(arr)
            if curr_max > max_val:
                max_val = curr_max
                max_arr_index = i


        keys.append(max_arr_index)    

    hex_k= [hex(k)[2:] for k in keys]
    print("number_trace",m,":",' '.join(hex_k))
# Out:
# /tmp/ipykernel_320355/3068833105.py:37: RuntimeWarning: Mean of empty slice.
#   x = x - x.mean(0)
# /tmp/ipykernel_320355/3068833105.py:38: RuntimeWarning: Mean of empty slice.
#   y = y - y.mean(0)
# /tmp/ipykernel_320355/3068833105.py:42: RuntimeWarning: invalid value encountered in divide
#   C = np.divide(C, repmat(xsq.T, 1, yc))
# number_trace 0 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 1 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# /tmp/ipykernel_320355/3068833105.py:43: RuntimeWarning: invalid value encountered in divide
#   C = np.divide(C, repmat(ysq, xc, 1))
# number_trace 2 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 3 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 4 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 5 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 6 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 7 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 8 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 9 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 10 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 11 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 12 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 13 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 14 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 15 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 16 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 17 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 18 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 19 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 20 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 21 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 22 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 23 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 24 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 25 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 26 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 27 : x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1 x1
# number_trace 28 : 98 11 22 7b 44 64 66 39 88 99 62 bb 5b bb ee 6f
# number_trace 29 : f8 11 22 7b 44 64 66 af 88 99 aa bb cc dd ee e
# number_trace 30 : f8 11 22 33 44 55 7a 77 88 99 aa bb cc dd ee e
# number_trace 31 : f8 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 32 : 98 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 33 : 98 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 34 : 98 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 35 : f8 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 36 : f8 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 37 : 98 11 22 7b 44 55 7a 77 88 99 aa bb cc dd ee ff
# number_trace 38 : 98 11 22 7b 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 39 : 98 11 22 7b 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 40 : 98 11 22 7b 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 41 : 98 11 22 7b 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 42 : 98 11 22 7b 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 43 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 44 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 45 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 46 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 47 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 48 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 49 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 50 : 98 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 51 : 0 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 52 : 0 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 53 : 0 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 54 : 0 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# number_trace 55 : 0 11 22 33 44 55 66 77 88 99 aa bb cc dd ee ff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 17
#      13     ph=np.array([hamming_d(n,plaintexts[index,byte]^key) for index, n in enumerate(iv(key,byte,m))])
#      14     ph=ph.reshape(ph.shape[0], 1)
# ---> 17     CC=(mycorr(ph,n_traces))
#      19     cc.append(CC)
#      20 max_val = -float("inf")
#
# Cell In [2], line 39, in mycorr(x, y)
#      37 x = x - x.mean(0)
#      38 y = y - y.mean(0)
# ---> 39 C = x.T.dot(y)
#      40 xsq = np.atleast_2d(np.sqrt(np.sum(x**2, 0)))
#      41 ysq = np.atleast_2d(np.sqrt(np.sum(y**2, 0)))
#
# KeyboardInterrupt:

# %%
print(' '.join(hex_k))
# Out:
# 5 f6 ad e8 ef 42 f8 68 61 dc 36 13 97 de 91 98

# %%
5 de ad be ef 42 0 68 61 63 6b 13 97 de 65 79
